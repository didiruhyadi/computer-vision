# %% [markdown]
# <a href="https://colab.research.google.com/github/didiruhyadi/computer-vision/blob/main/Lesson_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# this is lesson number 2

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
print("OpenCV version :",cv2.__version__)
# Out:
# OpenCV version : 4.1.2

# %%
# display image using opencv
image = cv2.imread('/content/sample_data/Udacity Computer Vision/dolphin.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.title("Dolphin")
plt.axis('off')

print("Image Shape :", image.shape)
print("Image type :", image.dtype)
# Out:
# Image Shape : (412, 330, 3)
# Image type : uint8
